# %%
import pandas as pd
import numpy as np
import geopandas
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("simplified_playing_fields_data.csv")
data
# Out:
#                 Neighborhood  Fields
# 0           Allegheny Center       2
# 1                  Allentown       1
# 2                  Arlington       1
# 3                 Banksville       2
# 4          Bedford Dwellings       2
# 5                  Beechview       3
# 6                Beltzhoover       3
# 7           Brighton Heights       7
# 8                  Brookline       6
# 9                    Carrick       5
# 10     Central Lawrenceville       2
# 11           Central Oakland       1
# 12             Crafton Hills       2
# 13                East Hills       1
# 14              East Liberty       1
# 15                    Elliot       2
# 16                  Fineview       1
# 17                  Garfield       1
# 18                Greenfield       2
# 19                 Hazelwood       4
# 20             Highland Park       4
# 21            Homewood South       1
# 22                   Larimer       1
# 23  Lincoln-Lemington-Belmar       2
# ...

# %%
# plt.figure(figsize=(20,10))
# plt.bar(x = data['Neighborhood'],
   #    height = data['Fields'])
# plt.xticks(rotation = 90)


ax = data.plot(kind='bar', figsize=(25,4),legend=False, fontsize=15)
ax.set_title("Number of Playgrounds in the Neighborhoods of Pittsburgh", fontsize=15)
ax.set_xlabel('Neighborhood', fontsize = 15)
ax.set_ylabel('Number of Playgrounds', fontsize = 15)
# Out:
# Text(0, 0.5, 'Number of Playgrounds')

# %%
neighborhoods = geopandas.read_file("Neighborhoods_.shp")
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: Unable to open Neighborhoods_.shx or Neighborhoods_.SHX. Set SHAPE_RESTORE_SHX config option to YES to restore or create it.
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-8-ca5824030b73> in <module>
# ----> 1 neighborhoods = geopandas.read_file("Neighborhoods_.shp")
#
# /opt/tljh/user/lib/python3.8/site-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#      94
#      95     with fiona_env():
# ---> 96         with reader(path_or_bytes, **kwargs) as features:
#      97
# ...
